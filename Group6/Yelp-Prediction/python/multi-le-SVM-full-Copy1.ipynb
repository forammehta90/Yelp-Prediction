# %%
x_train = [84.11, 85.99, 83.4, 69.58, 98.99]
x_test = [80.16, 77.96, 80.53, 51.3, 76.85]
y = [0, 20, 40, 60, 80]

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
 
objects = ('MLP', 'Random Forest', 'AdaBoost', 'Gaussian NB', 'Decision Tree')
y_pos = np.arange(len(objects))
 
plt.bar(y_pos, x_train, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Training Accuracy')
plt.title('Classifiers')
 
plt.show()

plt.bar(y_pos, x_test, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Test Accuracy')
plt.title('Classifiers')
 
plt.show()

# %%
x_train = [83.76, 90.1, 83.27, 71.3, 97.77]
x_test = [79.08, 78.52, 79.77, 62.45, 77.01]
y = [0, 20, 40, 60, 80]

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
 
objects = ('MLP', 'Random Forest', 'AdaBoost', 'Gaussian NB', 'Decision Tree')
y_pos = np.arange(len(objects))
 
plt.bar(y_pos, x_train, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Training Accuracy')
plt.title('Classifiers')
 
plt.show()

plt.bar(y_pos, x_test, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Test Accuracy')
plt.title('Classifiers')
 
plt.show()

# %%
x_train = [62.3, 65, 61.56]
x_test = [62.7, 62.8, 61.35]
y = [0, 40, 80]

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
 
objects = ('MLP', 'Random Forest', 'SVM')
y_pos = np.arange(len(objects))
 
plt.bar(y_pos, x_train, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Training Accuracy')
plt.xlabel('Classifiers')
plt.title('Multiclass Classification - Removing Outliers')
 
plt.show()

plt.bar(y_pos, x_test, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Test Accuracy')
plt.xlabel('Classifiers')
plt.title('Multiclass Classification - Removing Outliers')
 
plt.show()

# %%
x_train = [63.87, 68.87, 61.58]
x_test = [62.45, 62.46, 61.46]
y = [0, 40, 80]

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
 
objects = ('MLP', 'Random Forest', 'SVM')
y_pos = np.arange(len(objects))
 
plt.bar(y_pos, x_train, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Training Accuracy')
plt.xlabel('Classifiers')
plt.title('Multiclass Classification - Removing Outliers')
 
plt.show()

plt.bar(y_pos, x_test, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Test Accuracy')
plt.xlabel('Classifiers')
plt.title('Multiclass Classification - Removing Outliers')
 
plt.show()
